# %% [markdown]
# ## This is a demo for our project. The first couple of cells are to highlight some of the results gathered by data exploration. If you want to see more plots, add a new code cell and type "blockage_data_exploration." and select a plot (function) you want to see -- then run the cell.

# %%
# Import all our modules to give our program a demo
from exploration import blockage_data_exploration
from utils.visualization import visualization

# %%
# TODO: we should, for now, only call functions that display plots seen in our report (to show reproducibility)
blockage_data_exploration.visualize_mean_blockage_time()
# Out:
# The top 5 crossings with the longest blockage time are
#  CrossingID
# 743658M    5631.240816
# 859568M    4384.134615
# 758739G    1553.363636
# 743662C    1550.142857
# 755351K    1200.560932
# Name: BlockageDuration, dtype: float64

# %%
blockage_data_exploration.visualize_blalock_blockage_duration_intervals()

# %%
blockage_data_exploration.visualize_average_hourly_blockage_duration()

# %%
blockage_data_exploration.visualize_average_monthly_blockage_duration()
# Out:
# Variance of blockage duration per month (in seconds): [3478655.7287045843, 2349075.124676033, 1300951.5999098811, 1629852.5939236775, 2484701.9507592404, 3291868.96473608, 15653096.491061486, 2750749.1749662, 16927449.163039576, 67015636.548341654, 17367661.639802486, 2471165.25156619]

# %%
blockage_data_exploration.visualize_blockage_distribution()

# %%
blockage_data_exploration.visualize_weekday_frequency()

# %% [markdown]
# ### The simulation outputs a vehicle assignment for each of the emergencies that occur and total response time.

# %%
visualization.run_demo_dispatch_map()
